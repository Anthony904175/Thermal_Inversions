# %% [markdown]
# ## mRKS method
#
# Please check the original paper:\
# \[1\] [Ryabinkin, Kohut and Staroverov, PRL 115, 083001 (2015)](https://journals.aps.org/prl/abstract/10.1103/PhysRevLett.115.083001) \
# \[2\] [Ospadov, Ryabinkin and Staroverov, J. Chem. Phys. 146, 084103 (2017)](https://doi.org/10.1063/1.4975990) \
# \[3\] [Staroverov, Ospadov, Advances in Quantum Chemistry, Volume 79 (2019)](https://doi.org/10.1016/bs.aiq.2019.04.002).

# %% [markdown]
# First, build the input wavefunction using Psi4. Note that currently only Psi4.CIWavefunction supports two-particle density matrices (tpdm). CISD is used in this example.

# %%
import psi4
import matplotlib.pyplot as plt
import numpy as np

psi4.set_options({"save_jk" : True})
psi4.set_memory(int(2.50e9))
psi4.set_num_threads(10)
psi4.core.clean()

import n2v

import matplotlib as mpl
mpl.rcParams["font.size"] = 11
mpl.rcParams["font.family"] = "sans-serif"
mpl.rcParams["axes.edgecolor"] = "#eae8e9"

# %%
H2O = psi4.geometry( 
""" 
O 0.         0.         0.
H -0.4607    1.8327     0.
H 1.8897     0.         0.
noreorient
nocom
units bohr
symmetry c1
""" )

psi4.set_options({"reference" : "rhf",
                  "opdm": True,
                  "tpdm": True,
                  'DFT_SPHERICAL_POINTS': 74,  # Usually specify the DFT spherical grid is highly recommended.
                  'DFT_RADIAL_POINTS': 56,  # See [https://psicode.org/psi4manual/master/dft.html] for options.
                 })  # Spin-Restricted

# IMPORTANT NOTE: ONLY psi4.CIWavefunction or RHF is supported.
wfn = psi4.properties("detci/cc-pcvdz", return_wfn=True, molecule=H2O, properties=["dipole"])[1]
print(wfn)
inv = n2v.Inverter.from_wfn(wfn)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 20
#      12 psi4.set_options({"reference" : "rhf",
#      13                   "opdm": True,
#      14                   "tpdm": True,
#      15                   'DFT_SPHERICAL_POINTS': 74,  # Usually specify the DFT spherical grid is highly recommended.
#      16                   'DFT_RADIAL_POINTS': 56,  # See [https://psicode.org/psi4manual/master/dft.html] for options.
#      17                  })  # Spin-Restricted
#      19 # IMPORTANT NOTE: ONLY psi4.CIWavefunction or RHF is supported.
# ---> 20 wfn = psi4.properties("detci/cc-pcvdz", return_wfn=True, molecule=H2O, properties=["dipole"])[1]
#      21 print(wfn)
#      22 inv = n2v.Inverter.from_wfn(wfn)
#
# File /opt/anaconda3/envs/n2venv/lib/python3.12/site-packages/psi4/driver/driver.py:790, in properties(*args, **kwargs)
#     788 logger.info(f"Compute properties(): method={lowername}, basis={core.get_global_option('BASIS').lower()}, molecule={molecule.name()}, nre={'w/EFP' if hasattr(molecule, 'EFP') else molecule.nuclear_repulsion_energy()}")
#     789 logger.debug("w/EFP" if hasattr(molecule, "EFP") else pp.pformat(molecule.to_dict()))
# --> 790 wfn = procedures["properties"][lowername](lowername, molecule=molecule, **kwargs)
#     791 logger.info(f"Return properties(): {core.variable('CURRENT ENERGY')}")
#     793 basisstash.restore()
#
# File /opt/anaconda3/envs/n2venv/lib/python3.12/site-packages/psi4/driver/procrouting/proc.py:3544, in run_detci_property(name, **kwargs)
#    3542     ciwfn = run_detcas(name, **kwargs)
#    3543 else:
# -> 3544     ciwfn = run_detci(name, **kwargs)
#    3546 # All property names are just CI
#    3547 if 'CI' in name.upper():
#
# File /opt/anaconda3/envs/n2venv/lib/python3.12/site-packages/psi4/driver/procrouting/proc.py:4132, in run_detci(name, **kwargs)
#    4130 ref_wfn = kwargs.get('ref_wfn', None)
#    4131 if ref_wfn is None:
# -> 4132     ref_wfn = scf_helper(name, **kwargs)  # C1 certified
#    4134 # Ensure IWL files have been written
#    4135 proc_util.check_iwl_file_from_scf_type(core.get_global_option('SCF_TYPE'), ref_wfn)
#
# File /opt/anaconda3/envs/n2venv/lib/python3.12/site-packages/psi4/driver/procrouting/proc.py:1887, in scf_helper(name, post_scf, **kwargs)
#    1879     core.print_out(f""" Using potential file
#    1880                    {pol_embed_options["potfile"]}
#    1881                    for Polarizable Embedding calculation.\n""")
#    1882     scf_wfn.pe_state = solvent.pol_embed.CppeInterface(
#    1883         molecule=scf_molecule, options=pol_embed_options,
#    1884         basisset=scf_wfn.basisset()
#    1885     )
# -> 1887 e_scf = scf_wfn.compute_energy()
#    1888 for obj in [core, scf_wfn]:
#    1889     # set_variable("SCF TOTAL ENERGY")  # P::e SCF
#    1890     for pv in ["SCF TOTAL ENERGY", "CURRENT ENERGY", "CURRENT REFERENCE ENERGY"]:
#
# File /opt/anaconda3/envs/n2venv/lib/python3.12/site-packages/psi4/driver/procrouting/scf_proc/scf_iterator.py:82, in scf_compute_energy(self)
#      80     self.initialize_jk(self.memory_jk_)
#      81 else:
# ---> 82     self.initialize()
#      83 self.iteration_energies = []
#      85 try:
#
# File /opt/anaconda3/envs/n2venv/lib/python3.12/site-packages/psi4/driver/procrouting/scf_proc/scf_iterator.py:196, in scf_initialize(self)
#     194 if self.V_potential():
#     195     self.V_potential().build_collocation_cache(self.memory_collocation_)
# --> 196 core.timer_on("HF: Form core H")
#     197 self.form_H()
#     198 core.timer_off("HF: Form core H")
#
# RuntimeError:
# Fatal Error: Timer HF: Form core H is already on.
# Error occurred in file: /Users/runner/miniforge3/conda-bld/psi4_1709839991841/work/psi4/src/psi4/libqt/timer.cc on line: 280
# The most recent 5 function calls were:

# %%
# Build 1D grid
x = np.linspace(-3,5,801)
y = [0]
z = [0]
grid, shape = inv.eng.grid.generate_grid(x,y,z)

# Run the calculation with requested grid
inv.invert("mRKS", vxc_grid=grid, opt_max_iter=30, frac_old=0.8, 
                init="scan", sing=(1e-7, 1e-4, 1e-7, 1e-4))
# Out:
# Memory taken by ERI integral matrix and 2pdm is about: 0.015 GB.
# vxchole quadrature double integral starts (12284 points): ...........
#
# Totally 12284 grid points takes 1148.37s with max 256 points in a block.
# Iter: 1, Density Change: 1.96e-03, Eigenvalue Change: 3.80e+00, Potential Change: 2.78e-01.
# Iter: 2, Density Change: 3.90e-05, Eigenvalue Change: 8.89e-02, Potential Change: 8.96e-03.
# Iter: 3, Density Change: 8.18e-06, Eigenvalue Change: 5.73e-03, Potential Change: 7.79e-03.
# Iter: 4, Density Change: 4.56e-06, Eigenvalue Change: 5.75e-03, Potential Change: 7.43e-03.
# Iter: 5, Density Change: 2.97e-06, Eigenvalue Change: 5.72e-03, Potential Change: 7.29e-03.
# Iter: 6, Density Change: 2.35e-06, Eigenvalue Change: 5.66e-03, Potential Change: 7.20e-03.
# Iter: 7, Density Change: 2.11e-06, Eigenvalue Change: 5.60e-03, Potential Change: 7.13e-03.
# Iter: 8, Density Change: 2.01e-06, Eigenvalue Change: 5.54e-03, Potential Change: 7.07e-03.
# Iter: 9, Density Change: 1.95e-06, Eigenvalue Change: 5.47e-03, Potential Change: 7.01e-03.
# Iter: 10, Density Change: 1.92e-06, Eigenvalue Change: 5.42e-03, Potential Change: 6.96e-03.
# Iter: 11, Density Change: 1.89e-06, Eigenvalue Change: 5.36e-03, Potential Change: 6.90e-03.
# Iter: 12, Density Change: 1.87e-06, Eigenvalue Change: 5.31e-03, Potential Change: 6.84e-03.
# Iter: 13, Density Change: 1.85e-06, Eigenvalue Change: 5.26e-03, Potential Change: 6.79e-03.
# Iter: 14, Density Change: 1.83e-06, Eigenvalue Change: 5.21e-03, Potential Change: 6.74e-03.
# Iter: 15, Density Change: 1.82e-06, Eigenvalue Change: 5.17e-03, Potential Change: 6.68e-03.
# Iter: 16, Density Change: 1.80e-06, Eigenvalue Change: 5.12e-03, Potential Change: 6.63e-03.
# Iter: 17, Density Change: 1.79e-06, Eigenvalue Change: 5.08e-03, Potential Change: 6.58e-03.
# Iter: 18, Density Change: 1.78e-06, Eigenvalue Change: 5.04e-03, Potential Change: 6.53e-03.
# Iter: 19, Density Change: 1.76e-06, Eigenvalue Change: 5.00e-03, Potential Change: 6.48e-03.
# Iter: 20, Density Change: 1.75e-06, Eigenvalue Change: 4.96e-03, Potential Change: 6.43e-03.
# Iter: 21, Density Change: 1.74e-06, Eigenvalue Change: 4.92e-03, Potential Change: 6.38e-03.
# Iter: 22, Density Change: 1.73e-06, Eigenvalue Change: 4.88e-03, Potential Change: 6.33e-03.
# Iter: 23, Density Change: 1.71e-06, Eigenvalue Change: 4.85e-03, Potential Change: 6.29e-03.
# Iter: 24, Density Change: 1.70e-06, Eigenvalue Change: 4.81e-03, Potential Change: 6.24e-03.
# Iter: 25, Density Change: 1.69e-06, Eigenvalue Change: 4.77e-03, Potential Change: 6.19e-03.
# Iter: 26, Density Change: 1.68e-06, Eigenvalue Change: 4.74e-03, Potential Change: 6.15e-03.
# Iter: 27, Density Change: 1.67e-06, Eigenvalue Change: 4.70e-03, Potential Change: 6.10e-03.
# Iter: 28, Density Change: 1.66e-06, Eigenvalue Change: 4.67e-03, Potential Change: 6.06e-03.
# Iter: 29, Density Change: 1.65e-06, Eigenvalue Change: 4.63e-03, Potential Change: 6.01e-03.
# Iter: 30, Density Change: 1.64e-06, Eigenvalue Change: 4.60e-03, Potential Change: 5.97e-03.
# vxchole quadrature double integral starts (12284 points):
#
# Totally 801 grid points takes 19.69s with max 256 points in a block.

# %%
fig, ax = plt.subplots(dpi=200)
ax.plot(x, inv.grid_vxc, label="Inverted vxc")

# %% [markdown]
# ### It appears the following section is incomplete need to look into that
# ### Using grid, shape = inverter.eng.grid.generate_grid(x,y,z) command from Neon.jpynb clears the error however this section is still not complete

# %%
# The same potential can be visualized by running the calculation on a two or three dimensional grid. 
x = np.linspace(-5,5,501)
y = np.linspace(-5,5,501)
z = [0]
#grid, shape = inverter.generate_grids(x,y,z)
grid, shape = inv.eng.grid.generate_grid(x,y,z)

# Run the calculation with requested grid
inv.invert("mRKS", vxc_grid=grid, opt_max_iter=30, frac_old=0.8, 
                init="scan", sing=(1e-7, 1e-4, 1e-7, 1e-4))
# Out:
# Memory taken by ERI integral matrix and 2pdm is about: 0.015 GB.
# Iter: 1, Density Change: 1.96e-03, Eigenvalue Change: 3.80e+00, Potential Change: 2.78e-01.
# Iter: 2, Density Change: 3.90e-05, Eigenvalue Change: 8.89e-02, Potential Change: 8.96e-03.
# Iter: 3, Density Change: 8.18e-06, Eigenvalue Change: 5.73e-03, Potential Change: 7.79e-03.
# Iter: 4, Density Change: 4.56e-06, Eigenvalue Change: 5.75e-03, Potential Change: 7.43e-03.
# Iter: 5, Density Change: 2.97e-06, Eigenvalue Change: 5.72e-03, Potential Change: 7.29e-03.
# Iter: 6, Density Change: 2.35e-06, Eigenvalue Change: 5.66e-03, Potential Change: 7.20e-03.
# Iter: 7, Density Change: 2.11e-06, Eigenvalue Change: 5.60e-03, Potential Change: 7.13e-03.
# Iter: 8, Density Change: 2.01e-06, Eigenvalue Change: 5.54e-03, Potential Change: 7.07e-03.
# Iter: 9, Density Change: 1.95e-06, Eigenvalue Change: 5.47e-03, Potential Change: 7.01e-03.
# Iter: 10, Density Change: 1.92e-06, Eigenvalue Change: 5.42e-03, Potential Change: 6.96e-03.
# Iter: 11, Density Change: 1.89e-06, Eigenvalue Change: 5.36e-03, Potential Change: 6.90e-03.
# Iter: 12, Density Change: 1.87e-06, Eigenvalue Change: 5.31e-03, Potential Change: 6.84e-03.
# Iter: 13, Density Change: 1.85e-06, Eigenvalue Change: 5.26e-03, Potential Change: 6.79e-03.
# Iter: 14, Density Change: 1.83e-06, Eigenvalue Change: 5.21e-03, Potential Change: 6.74e-03.
# Iter: 15, Density Change: 1.82e-06, Eigenvalue Change: 5.17e-03, Potential Change: 6.68e-03.
# Iter: 16, Density Change: 1.80e-06, Eigenvalue Change: 5.12e-03, Potential Change: 6.63e-03.
# Iter: 17, Density Change: 1.79e-06, Eigenvalue Change: 5.08e-03, Potential Change: 6.58e-03.
# Iter: 18, Density Change: 1.78e-06, Eigenvalue Change: 5.04e-03, Potential Change: 6.53e-03.
# Iter: 19, Density Change: 1.76e-06, Eigenvalue Change: 5.00e-03, Potential Change: 6.48e-03.
# Iter: 20, Density Change: 1.75e-06, Eigenvalue Change: 4.96e-03, Potential Change: 6.43e-03.
# Iter: 21, Density Change: 1.74e-06, Eigenvalue Change: 4.92e-03, Potential Change: 6.38e-03.
# Iter: 22, Density Change: 1.73e-06, Eigenvalue Change: 4.88e-03, Potential Change: 6.33e-03.
# Iter: 23, Density Change: 1.71e-06, Eigenvalue Change: 4.85e-03, Potential Change: 6.29e-03.
# Iter: 24, Density Change: 1.70e-06, Eigenvalue Change: 4.81e-03, Potential Change: 6.24e-03.
# Iter: 25, Density Change: 1.69e-06, Eigenvalue Change: 4.77e-03, Potential Change: 6.19e-03.
# Iter: 26, Density Change: 1.68e-06, Eigenvalue Change: 4.74e-03, Potential Change: 6.15e-03.
# Iter: 27, Density Change: 1.67e-06, Eigenvalue Change: 4.70e-03, Potential Change: 6.10e-03.
# Iter: 28, Density Change: 1.66e-06, Eigenvalue Change: 4.67e-03, Potential Change: 6.06e-03.
# Iter: 29, Density Change: 1.65e-06, Eigenvalue Change: 4.63e-03, Potential Change: 6.01e-03.
# Iter: 30, Density Change: 1.64e-06, Eigenvalue Change: 4.60e-03, Potential Change: 5.97e-03.
# vxchole quadrature double integral starts (12284 points): ...........
#
# Totally 251001 grid points takes 1335.92s with max 256 points in a block.

# %%
fig = plt.figure(figsize=plt.figaspect(2.))
ax = fig.add_subplot(2, 1, 2, projection='3d')
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

surf = ax.plot_surface(x, y, inv.grid_vxc, rstride=1, cstride=1,
                       linewidth=0, antialiased=False)
ax.set_zlim(-1, 1)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 9
#       6 R = np.sqrt(X**2 + Y**2)
#       7 Z = np.sin(R)
# ----> 9 surf = ax.plot_surface(x, y, inv.grid_vxc, rstride=1, cstride=1,
#      10                        linewidth=0, antialiased=False)
#      11 ax.set_zlim(-1, 1)
#      13 plt.show()
#
# File /opt/anaconda3/envs/n2venv/lib/python3.12/site-packages/mpl_toolkits/mplot3d/axes3d.py:1700, in Axes3D.plot_surface(self, X, Y, Z, norm, vmin, vmax, lightsource, **kwargs)
#    1697 had_data = self.has_data()
#    1699 if Z.ndim != 2:
# -> 1700     raise ValueError("Argument Z must be 2-dimensional.")
#    1702 Z = cbook._to_unmasked_float_array(Z)
#    1703 X, Y, Z = np.broadcast_arrays(X, Y, Z)
#
# ValueError: Argument Z must be 2-dimensional.

# %%
fig = plt.figure(figsize=plt.figaspect(2.))
ax = fig.add_subplot(2, 1, 2, projection='3d')
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1,
                       linewidth=0, antialiased=False)
ax.set_zlim(-1, 1)

plt.show()
